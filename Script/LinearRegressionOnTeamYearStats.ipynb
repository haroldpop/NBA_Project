# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_original = pd.read_csv('TeamStats10-21.csv')
df = df_original.copy()

# %%
df.drop(columns = 'Unnamed: 27', inplace = True)
df
# Out:
#                     TEAM    GP     W     L   WIN%   MIN    PTS   FGM   FGA  \
# 0          Atlanta Hawks  82.0  44.0  38.0  0.537  48.1   95.0  36.2  78.4
# 1         Boston Celtics  82.0  56.0  26.0  0.683  48.2   96.5  36.9  75.8
# 2      Charlotte Bobcats  82.0  34.0  48.0  0.415  48.3   93.3  35.0  77.6
# 3          Chicago Bulls  82.0  62.0  20.0  0.756  48.4   98.6  37.1  80.3
# 4    Cleveland Cavaliers  82.0  19.0  63.0  0.232  48.2   95.5  35.2  81.1
# ..                   ...   ...   ...   ...    ...   ...    ...   ...   ...
# 335     Sacramento Kings  72.0  31.0  41.0  0.431  48.1  113.7  42.6  88.6
# 336    San Antonio Spurs  72.0  33.0  39.0  0.458  48.6  111.1  41.9  90.5
# 337      Toronto Raptors  72.0  27.0  45.0  0.375  48.1  111.3  39.7  88.7
# 338            Utah Jazz  72.0  52.0  20.0  0.722  48.2  116.4  41.3  88.1
# 339   Washington Wizards  72.0  34.0  38.0  0.472  48.3  116.6  43.2  90.9
#
#       FG%  ...  DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD  +/-
# 0    46.2  ...  30.0  39.3  22.0  13.6  6.1  4.2   4.2  19.0  18.5 -0.8
# 1    48.6  ...  31.0  38.8  23.4  14.6  8.2  4.2   4.4  20.5  20.2  5.4
# 2    45.1  ...  29.8  40.1  21.1  14.5  6.4  5.3   6.0  20.0  21.1 -4.0
# 3    46.2  ...  32.4  44.2  22.3  14.2  7.2  5.7   5.8  20.0  20.1  7.3
# 4    43.4  ...  29.9  40.3  21.0  14.2  6.6  4.2   6.0  20.1  21.3 -9.0
# ..    ...  ...   ...   ...   ...   ...  ...  ...   ...   ...   ...  ...
# 335  48.1  ...  32.0  41.4  25.5  13.4  7.5  5.0   4.7  19.4  18.7 -3.7
# 336  46.2  ...  34.6  43.9  24.4  11.4  7.0  5.1   5.1  18.0  18.6 -1.7
# 337  44.8  ...  32.1  41.6  24.1  13.2  8.6  5.4   5.6  21.2  19.5 -0.5
# 338  46.8  ...  37.6  48.3  23.7  14.2  6.6  5.2   3.9  18.5  19.0  9.3
# 339  47.5  ...  35.5  45.2  25.5  14.4  7.3  4.1   4.8  21.6  22.0 -1.8
#
# [340 rows x 27 columns]

# %%
df['TEAM'][df['TEAM'] == 'Charlotte Hornets']
# Out:
# 2      Charlotte Hornets
# 33     Charlotte Hornets
# 65     Charlotte Hornets
# 96     Charlotte Hornets
# 127    Charlotte Hornets
# 158    Charlotte Hornets
# 189    Charlotte Hornets
# 220    Charlotte Hornets
# 251    Charlotte Hornets
# 282    Charlotte Hornets
# 313    Charlotte Hornets
# Name: TEAM, dtype: object

# %%
df['TEAM'][df['TEAM'] == 'Charlotte Bobcats'] = 'Charlotte Hornets'
df['TEAM'][df['TEAM'] == 'New Orleans Hornets'] = 'New Orleans Pelicans'
# Out:
# <ipython-input-50-90269ed5b417>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TEAM'][df['TEAM'] == 'Charlotte Bobcats'] = 'Charlotte Hornets'
# <ipython-input-50-90269ed5b417>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TEAM'][df['TEAM'] == 'New Orleans Hornets'] = 'New Orleans Pelicans'

# %%
df.columns
# Out:
# Index(['TEAM', 'GP', 'W', 'L', 'WIN%', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%',
#        '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST',
#        'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', '+/-'],
#       dtype='object')

# %%
#split the dataFrame by year
separate_year_idx = np.unique(np.where(df.isnull())[0])
list_df = [df[:30]]
for idx in separate_year_idx:
    list_df.append(df[idx + 1:idx + 31])

ex_shape = list_df[0].shape
for df in list_df[1:]:
    if df.shape != ex_shape:
        print('Error')

# %%
teams = df['TEAM'].unique()
team = teams[0]
print(team)
# Out:
# Atlanta Hawks

# %%
df_team = df[df['TEAM'] == team]
df_team
# Out:
#               TEAM    GP     W     L   WIN%   MIN    PTS   FGM   FGA   FG%  \
# 0    Atlanta Hawks  82.0  44.0  38.0  0.537  48.1   95.0  36.2  78.4  46.2
# 31   Atlanta Hawks  66.0  40.0  26.0  0.606  49.0   96.6  36.8  81.0  45.4
# 62   Atlanta Hawks  82.0  44.0  38.0  0.537  48.4   98.0  37.6  81.0  46.4
# 93   Atlanta Hawks  82.0  38.0  44.0  0.463  48.4  101.0  37.3  81.6  45.8
# 124  Atlanta Hawks  82.0  60.0  22.0  0.732  48.1  102.5  38.1  81.7  46.6
# 155  Atlanta Hawks  82.0  48.0  34.0  0.585  48.4  102.8  38.6  84.4  45.8
# 186  Atlanta Hawks  82.0  43.0  39.0  0.524  48.5  103.2  38.1  84.4  45.1
# 217  Atlanta Hawks  82.0  24.0  58.0  0.293  48.1  103.4  38.2  85.5  44.6
# 248  Atlanta Hawks  82.0  29.0  53.0  0.354  48.4  113.3  41.4  91.8  45.1
# 279  Atlanta Hawks  67.0  20.0  47.0  0.299  48.6  111.8  40.6  90.6  44.9
# 310  Atlanta Hawks  72.0  41.0  31.0  0.569  48.3  113.7  40.8  87.2  46.8
#
#      ...  DREB   REB   AST   TOV  STL  BLK  BLKA    PF   PFD  +/-
# 0    ...  30.0  39.3  22.0  13.6  6.1  4.2   4.2  19.0  18.5 -0.8
# 31   ...  31.3  41.2  22.4  14.0  8.1  4.6   4.7  17.8  19.1  3.4
# 62   ...  31.6  40.9  24.5  14.9  8.1  4.5   4.3  18.0  18.8  0.4
# 93   ...  31.3  40.0  24.9  15.3  8.3  4.0   4.3  19.2  20.0 -0.5
# 124  ...  31.8  40.6  25.7  14.2  9.1  4.6   4.9  17.8  19.6  5.4
# 155  ...  33.8  42.1  25.6  15.0  9.1  5.9   5.0  19.1  18.3  3.6
# 186  ...  34.1  44.3  23.6  15.8  8.2  4.8   5.2  18.2  21.6 -0.9
# 217  ...  32.8  41.9  23.7  15.5  7.8  4.2   5.5  19.6  20.3 -5.5
# 248  ...  34.5  46.1  25.8  17.0  8.2  5.1   5.5  23.6  22.2 -6.0
# 279  ...  33.4  43.3  24.0  16.2  7.8  5.1   6.4  23.1  21.0 -8.0
# 310  ...  35.1  45.6  24.1  13.2  7.0  4.8   5.0  19.3  19.8  2.3
#
# [11 rows x 27 columns]

# %%
def r_square(yhat, y):
    y_mean = np.mean(y)
    num = np.sum((yhat - y)**2)
    den = np.sum((y - y_mean)**2)
    print(num, den)
    return 1 - (num / den)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import seaborn as sns

scaler = StandardScaler()

df_show = df_team.drop(columns = ['TEAM', 'W', 'L', 'WIN%'])
list_attributes = list(df_show.columns)

X = np.array(df_team.drop(columns = ['TEAM', 'W', 'L', 'WIN%']))
y = np.array(df_team['W'])
y = y.reshape(-1, 1)

X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1, shuffle = True)

print(X.shape, X_train.shape, X_test.shape)
print(y.shape, y_train.shape, y_test.shape)


reg = LinearRegression()
reg.fit(X_train, y_train)
yhat = reg.predict(X_test)
print(y_test, yhat)
df_plot = pd.DataFrame(reg.coef_, columns = list_attributes)
plt.figure(figsize = (20, 10))
sns.barplot(data = df_plot)
plt.show()
# Out:
# (11, 23) (10, 23) (1, 23)
# (11, 1) (10, 1) (1, 1)
# [[0.35400522]] [[-0.20065254]]

# %% [markdown]
# **Use manually written functions if we want to plot the loss, ...**

# %% [markdown]
# The linear regression is clearly not a good model for our problem

# %%
from sklearn.preprocessing import PolynomialFeatures

scaler = StandardScaler()

X = np.array(df_team.drop(columns = ['TEAM', 'W', 'L', 'WIN%']))
y = np.array(df_team['W'])
y = y.reshape(-1, 1)

poly = PolynomialFeatures(degree = 2)
X = poly.fit_transform(X)
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1, shuffle = True)


reg = LinearRegression(fit_intercept = False) #already done in PolynomialFeatures
reg.fit(X_train, y_train)
yhat = reg.predict(X_test)
print(y_test, yhat)
# Out:
# [[0.35400522]] [[0.35400522]]

# %% [markdown]
# Good results

# %% [markdown]
# **Calculate Cross-Validation score to highlights it and for every team**

# %% [markdown]
# **Make it manually to truly understand what's going on inside**

# %% [markdown]
# **Implement Locally weighted regression**

# %% [markdown]
# ### Test for every team

# %%
teams = df['TEAM'].unique()
for team in teams:
    print(team)
    if type(team) == str: #avoid nan values
        df_team = df[df['TEAM'] == team]

        scaler = StandardScaler()

        X = np.array(df_team.drop(columns = ['TEAM', 'W', 'L', 'WIN%']))
        y = np.array(df_team['W'])
        y = y.reshape(-1, 1)

        poly = PolynomialFeatures(degree = 2)
        X = poly.fit_transform(X)
        X = scaler.fit_transform(X)
        y = scaler.fit_transform(y)

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1, shuffle = True)


        reg = LinearRegression(fit_intercept = False) #add of intercept already done in PolynomialFeatures
        reg.fit(X_train, y_train)
        yhat = reg.predict(X_test)
        print(y_test, yhat)
# Out:
# Atlanta Hawks
# [[-0.94401391]] [[-0.94401391]]
# Boston Celtics
# [[-0.95828607]] [[-0.95828607]]
# Charlotte Hornets
# [[0.36084798]] [[0.36084798]]
# Chicago Bulls
# [[0.81013862]] [[0.81013862]]
# Cleveland Cavaliers
# [[-0.8227375]] [[-0.8227375]]
# Dallas Mavericks
# [[0.12418076]] [[0.12418076]]
# Denver Nuggets
# [[1.28765945]] [[1.28765945]]
# Detroit Pistons
# [[-1.48471804]] [[-1.48471804]]
# Golden State Warriors
# [[0.5370721]] [[0.5370721]]
# Houston Rockets
# [[-0.25018945]] [[-0.25018945]]
# Indiana Pacers
# [[-1.]] [[-1.]]
# Los Angeles Clippers
# [[-0.79735759]] [[-0.79735759]]
# Los Angeles Lakers
# [[-0.85755503]] [[-0.85755503]]
# Memphis Grizzlies
# [[-0.81686482]] [[-0.81686482]]
# Miami Heat
# [[-0.70356236]] [[-0.70356236]]
# Milwaukee Bucks
# [[1.70667198]] [[1.70667198]]
# Minnesota Timberwolves
# [[1.21732717]] [[1.21732717]]
# New Jersey Nets
# [[-1.]] [[-1.]]
# New Orleans Pelicans
# [[1.67574473]] [[1.67574473]]
# New York Knicks
# [[-1.43003645]] [[-1.43003645]]
# Oklahoma City Thunder
# [[-0.12927545]] [[-0.12927545]]
# Orlando Magic
# [[-0.64566505]] [[-0.64566505]]
# Philadelphia 76ers
# [[1.05657754]] [[1.05657754]]
# Phoenix Suns
# [[-0.80387771]] [[-0.80387771]]
# Portland Trail Blazers
# [[1.16479873]] [[1.16479873]]
# Sacramento Kings
# [[0.58156909]] [[0.58156909]]
# San Antonio Spurs
# [[0.89034511]] [[0.89034511]]
# Toronto Raptors
# [[0.53959246]] [[0.53959246]]
# Utah Jazz
# [[0.73977464]] [[0.73977464]]
# Washington Wizards
# [[1.13684085]] [[1.13684085]]
# nan
# Brooklyn Nets
# [[-0.10742136]] [[-0.10742136]]
# LA Clippers
# [[1.35343108]] [[1.35343108]]
